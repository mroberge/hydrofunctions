# %%
import hydrofunctions as hf
# %matplotlib inline
hf.__version__
# Out:
# '0.1.7'

# %%
hf.draw_map()
# Out:
# <p>Use <a href="http://hydrocloud.org" target="_blank">HydroCloud.org</a> to find a stream gauge. Click on the dots to learn more about a site.</p><iframe src=http://hydrocloud.org/ width=700 height=400></iframe>

# %%
# request data for our two sites for a three-year period.
streamid = ['01197000', '01589352']
sites = hf.NWIS(streamid, start_date='2002-01-01', end_date='2005-01-01')
sites.get_data()
sites.ok
# Out:
# True

# %%
Q = sites.df()
Q.head()
# Out:
#             USGS:01197000:00060:00003 USGS:01197000:00060:00003_qualifiers  \
# 2002-01-01                       29.8                                    A
# 2002-01-02                       29.3                                    A
# 2002-01-03                       29.8                                    A
# 2002-01-04                       29.0                                    A
# 2002-01-05                       29.0                                    A
#
#             USGS:01589352:00060:00003 USGS:01589352:00060:00003_qualifiers
# 2002-01-01                       20.0                                  A e
# 2002-01-02                       20.0                                  A e
# 2002-01-03                       20.0                                  A e
# 2002-01-04                       19.0                                  A e
# 2002-01-05                       19.1                                    A

# %%
Q = Q.rename(columns={'USGS:01197000:00060:00003': "MA", 'USGS:01589352:00060:00003': "MD"})
Q = Q.drop(['USGS:01197000:00060:00003_qualifiers','USGS:01589352:00060:00003_qualifiers'], axis=1)
Q.head()
# Out:
#               MA    MD
# 2002-01-01  29.8  20.0
# 2002-01-02  29.3  20.0
# 2002-01-03  29.8  20.0
# 2002-01-04  29.0  19.0
# 2002-01-05  29.0  19.1

# %%
Q.plot()

# %%
hf.flow_duration(Q)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x22caab426a0>)

# %%
Q.describe()
# Out:
#                 MA           MD
# count  1097.000000  1097.000000
# mean    113.055515   105.764986
# std     136.629521   194.461983
# min      13.000000     8.730000
# 25%      43.100000    33.600000
# 50%      74.300000    52.400000
# 75%     123.000000    87.800000
# max    1360.000000  2400.000000

# %%
hf.flow_duration??

# %%
Q.plot(loglog=True, legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a6a04e7bdabf> in <module>
#       1 Q.plot(loglog=True, legend=False)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

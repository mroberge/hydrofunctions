# %% [markdown]
# # Different Ways to Select NWIS Sites
# The National Water Information System (NWIS) makes data available for approximately 1.9 Million different locations in the US and Territories. This page explains several ways that you can find sites.

# %%
# First things first
import hydrofunctions as hf

# %% [markdown]
# ### There are four methods for specifying which sites you want to request data for:
#
# * Request data for a site or a list of sites
# * Request data for all sites in a state
# * Request data for all sites in a county or list of counties
# * Request data for all sites inside of bounding box
#
# *We'll give examples for each of these methods below.*

# %% [markdown]
# ## Requesting data for a site or a list of sites
# Most USGS site names are between 8-11 digits long. You can use the `draw_map()` function
# to create an interactive map with 8,000 active stream gages from the [Gages-II](https://water.usgs.gov/GIS/metadata/usgswrd/XML/gagesII_Sept2011.xml) dataset.

# %%
hf.draw_map()
# Out:
# <p>Use <a href="http://hydrocloud.org" target="_blank">HydroCloud.org</a> to find a stream gauge. Click on the dots to learn more about a site.</p><iframe src=http://hydrocloud.org/ width=700 height=400></iframe>

# %%
# Select a single site, '01581960'
Beetree = hf.NWIS('01581960').get_data()

# %%
Beetree.df()
# Out:
#             USGS:01581960:00060:00003 USGS:01581960:00060:00003_qualifiers
# datetime
# 2018-03-05                       10.6                                    P

# %%
# Select a list of sites:
sites = ['01580000', '01585500', '01589330']
Baltimore = hf.NWIS(sites).get_data()

# %%
Baltimore.df()
# Out:
#             USGS:01580000:00060:00003 USGS:01580000:00060:00003_qualifiers  \
# dateTime
# 2018-03-05                      125.0                                    P
#
#             USGS:01585500:00060:00003 USGS:01585500:00060:00003_qualifiers  \
# dateTime
# 2018-03-05                       1.44                                    P
#
#             USGS:01589330:00060:00003 USGS:01589330:00060:00003_qualifiers
# dateTime
# 2018-03-05                        3.6                                    P

# %% [markdown]
# ## Request Data by State or Territory
# Use the two-letter [state postal code](https://www.bls.gov/cew/cewedr10.htm) to retrieve all of the stations
# inside of a state. You can only request one state at a time. Lists are not accepted.

# %%
# Request data for all stations in Puerto Rico.
PR = hf.NWIS(stateCd='PR').get_data()

# %%
# List the names for all of the sites in PR
PR.siteName
# Out:
# ['CIDRA SITE, CIDRA, PR',
#  'OJO DE GUILLO SPRING, MANATI, PR',
#  'OJO DE AGUA SPRING, VEGA BAJA, PR',
#  'CANAL PRINCIPAL DIVERSION BLW FOREBAY, ISABELA, PR',
#  'RIO GUAJATACA AT LARES, PR',
#  'RIO GUAJATACA ABV LAGO DE GUAJATACA, PR',
#  'CANAL DE DERIVACION AT LAGO DE GUAJATACA, PR',
#  'CANAL DE MOCA ABV LAGO REGULADOR (E13) ISABELA, PR',
#  'CANAL MOCA ABV AGUADILLA PLANT, AGUADILLA, PR',
#  'RIO GUAJATACA BLW LAGO GUAJATACA, PR',
#  'RIO GUAJATACA ABV MOUTH NR QUEBRADILLAS, PR',
#  'RIO CAMUY NR LARES, PR',
#  'RIO CRIMINALES NR LARES, PR',
#  'RIO CAMUY AT TRES PUEBLOS SINKHOLE, LARES PR',
#  'RIO CAMUY NR BAYANEY, PR',
#  'RIO CAMUY NR HATILLO, PR',
#  'RIO CAMUY NR CAMUY, PR',
#  'RIO GRANDE DE ARECIBO NR ADJUNTAS, PR',
#  'RIO PELLEJAS AT CENTRAL PELLEJAS, PR',
#  'RIO PELLEJAS ABV CENTRAL PELLEJAS, PR',
#  'RIO PELLEJAS BLW CENTRAL PELLEJAS, PR',
#  'RIO PELLEJAS NR UTUADO, PR',
#  'RIO GRANDE DE ARECIBO ABV UTUADO, PR',
#  'RIO VIVI BLW HACIENDA EL PROGRESO, PR',
#  'RIO VIVI NR CENTRAL PELLEJAS, PR',
#  'RIO VIVI NR UTUADO, PR',
#  'RIO GRANDE DE ARECIBO BLW UTUADO, PR',
#  'RIO SALIENTE AT COABEY NR JAYUYA, PR',
#  'RIO JAUCA AT PASO PALMA, PR',
#  'RIO CAONILLAS AT PASO PALMA, PR',
#  'RIO CAONILLAS NR UTUADO, PR',
#  'RIO CAONILLAS BLW LAGO CAONILLAS TUNNEL, PR',
#  'RIO YUNES AT HWY 140 NR FLORIDA, PR',
#  'RIO LIMON ABV LAGO DOS BOCAS, PR',
#  'RIO GRANDE DE ARECIBO BLW LAGO DOS BOCAS DAM, PR',
#  'RIO GDE. DE ARECIBO BLW LAGO DOS BOCAS NR FLORIDA',
#  'RIO GRANDE DE ARECIBO NR SAN PEDRO, PR',
#  'RIO GRANDE DE ARECIBO ABV ARECIBO, PR',
#  'RIO TANAMA NR TANAMA, UTUADO, PR',
#  'RIO GUAONICA NEAR UTUADO, UTUADO, PR',
#  'RIO TANAMA NR UTUADO, PR',
#  'RIO TANAMA AT CHARCO HONDO, PR',
#  'RIO GRANDE DE ARECIBO AT CENTRAL CAMBALACHE, PR',
#  'RIO OROCOVIS AT OROCOVIS, PR',
#  'RIO GRANDE DE MANATI NR MOROVIS, PR',
#  'RIO SANA MUERTO NR OROCOVIS, PR',
#  'RIO BAUTA NR DIVISORIA, PR',
#  'RIO BAUTA NR OROCOVIS, PR',
#  'RIO GRANDE DE MANATI AT CIALES, PR',
#  'RIO GRANDE DE MANATI AT HWY 145 AT CIALES, PR',
#  'RIO CIALITOS AT HWY 649 AT CIALES, PR',
#  'RIO GRANDE DE MANATI AT HWY 2 NR MANATI, PR',
#  'RIO CIBUCO BLW COROZAL, PR',
#  'RIO MAVILLA NR COROZAL, PR',
#  'RIO UNIBON NR MOROVIS, PR',
#  'RIO CIBUCO AT VEGA BAJA, PR',
#  'RIO CIBUCO AT CENTRAL SAN VICENTE, PR',
#  'LAGO CARITE AT SPILLWAY, PR',
#  'RIO DE LA PLATA AT LAGO CARITE, PR',
#  'RIO DE LA PLATA AT PROYECTO LA PLATA, PR',
#  'RIO USABON AT HWY 162 NR BARRANQUITAS, PR',
#  'RIO DE LA PLATA AT COMERIO, PR',
#  'RIO GUADIANA NR GUADIANA, NARANJITO PR',
#  'RIO GUADIANA AT GUADIANA, PR',
#  'RIO DE LA PLATA BLW LA PLATA DAMSITE, PR',
#  'RIO LAJAS AT TOA ALTA, PR',
#  'RIO DE LA PLATA AT HWY 2 NR TOA ALTA, PR',
#  'RIO DE BAYAMON AT ARENAS, PR',
#  'RIO SABANA AT VISTA MONTE, PR',
#  'QUEBRADA PRIETA NR CIDRA, PR',
#  'RIO DE BAYAMON BLW LAGO DE CIDRA DAM, PR',
#  'RIO DE BAYAMON AT HWY 174 NR BAYAMON, PR',
#  'RIO DE BAYAMON NR BAYAMON, PR',
#  'RIO DE BAYAMON AT BAYAMON, PR',
#  'QUEBRADA LAS CURIAS BLW LAS CURIAS OUTFLOW, PR',
#  'QUEBRADA LAS CURIAS NR RIO PIEDRAS, PR',
#  'QUEBRADA LAS CURIAS TRIBUTARY NR CAIMITO, PR',
#  'RIO PIEDRAS AT EL SENORIAL, PR',
#  'RIO PIEDRAS NR RIO PIEDRAS, PR',
#  'RIO PIEDRAS AT RIO PIEDRAS, PR',
#  'RIO PIEDRAS AT HATO REY, PR',
#  'QUEBRADA JOSEFINA AT PUERTO NUEVO, PR',
#  'QUEBRADA JOSEFINA AT PINERO AVENUE, PR',
#  'QUEBRADA MARGARITA AT QUEBRADA HEIGHTS, PR',
#  'QDA. MARGARITA AT CAPARRA INTER. NR GUAYNABO, PR',
#  'RIO GRANDE DE LOIZA AT QUEBRADA ARENAS, PR',
#  'QUEBRADA BLANCA AT EL JAGUAL, PR',
#  'QUEBRADA SALVATIERRA NR SAN LORENZO, PR',
#  'RIO CAYAGUAS AT CERRO GORDO, PR',
#  'RIO GRANDE DE LOIZA AT HWY 183 SAN LORENZO, PR',
#  'RIO TURABO ABV BORINQUEN, PR',
#  'RIO TURABO AT BORINQUEN, PR',
#  'RIO GRANDE DE LOIZA AT CAGUAS, PR',
#  'RIO CAGUITAS NR AGUAS BUENAS, PR',
#  'RIO CAGUITAS NR CAGUAS, PR',
#  'RIO CAGUITAS AT VILLA BLANCA AT CAGUAS, PR',
#  'RIO BAIROA ABV BAIROA, CAGUAS, PR',
#  'RIO BAIROA AT BAIROA, PR',
#  'QUEBRADA CAIMITO NR JUNCOS, PR',
#  'RIO GURABO BLW EL MANGO, PR',
#  'RIO VALENCIANO NR JUNCOS, PR',
#  'QUEBRADA MAMEY NR GURABO, PR',
#  'RIO GURABO AT GURABO, PR',
#  'RIO CANAS AT RIO CANAS, PR',
#  'RIO GRANDE DE LOIZA BLW LOIZA DAMSITE, PR',
#  'QUEBRADA GRANDE AT BO. DOS BOCAS, PR',
#  'RIO CANOVANILLAS NR LOIZA, PR',
#  'RIO CANOVANAS NR CAMPO RICO, PR',
#  'RIO HERRERA NR COLONIA DOLORES, PR',
#  'RIO ESPIRITU SANTO ABV EL VERDE, PR',
#  'RIO ESPIRITU SANTO NR EL VERDE, PR',
#  'QUEBRADA TORONJA AT EL VERDE, PR',
#  'RIO ESPIRITU SANTO NR RIO GRANDE, PR',
#  'RIO GRANDE NR EL VERDE, PR',
#  'RIO MAMEYES NR SABANA, PR',
#  'RIO MAMEYES AT HWY 191 AT MAMEYES, PR',
#  'RIO MAMEYES AT MAMEYES, PR',
#  'RIO SABANA AT SABANA, PR',
#  'RIO FAJARDO ABV FAJARDO, PR',
#  'RIO FAJARDO AT PARAISO NR FAJARDO, PR',
#  'RIO FAJARDO NR FAJARDO, PR',
#  'RIO FAJARDO AT FAJARDO, PR',
#  'QUEBRADA PALMA AT DAGUAO, PR',
#  'QUEBRADA GUABA NR NAGUABO, PR',
#  'RIO ICACOS NR NAGUABO, PR',
#  'RIO BLANCO NR FLORIDA, PR',
#  'RIO BLANCO AT RIO BLANCO, PR',
#  'RIO BLANCO BLW LA FE, PR',
#  'RIO HUMACAO AT LAS PIEDRAS, PR',
#  'RIO HUMACAO NR HUMACAO, PR',
#  'RIO HUMACAO AT HWY 3 AT HUMACAO, PR',
#  'RIO GUAYANES NR COLONIA LAURA, PR',
#  'RIO GUAYANES NR YABUCOA, PR',
#  'RIO LIMONES NR YABUCOA, PR',
#  'RIO GUAYANES AT CENTRAL ROIG, PR',
#  'RIO MAUNABO AT LIZAS, PR',
#  'RIO MAUNABO NR MAUNABO, PR',
#  'RIO GRANDE DE PATILLAS NR PATILLAS, PR',
#  'RIO MARIN NR PATILLAS, PR',
#  'RIO GRANDE DE PATILLAS AT LAGO PATILLAS, PR',
#  'CANAL DE PATILLAS AT FOREBAY, PR',
#  'CANAL DE PATILLAS ABV GUAYAMA FILTRATION PLANT, PR',
#  'CANAL DE PATILLAS BLW GUAYAMA FILTRATION PLANT, PR',
#  'CANAL DE PATILLAS ABV AES INTAKE AT GUAYAMA, PR',
#  'CANAL DE PATILLAS ABV EL LEGADO INTAKE, PR',
#  'CANAL DE PATILLAS AT INTAKE 113 SALINAS, PR',
#  'CANAL DE PATILLAS AT INTAKE 123, SALINAS PR',
#  'RIO GRANDE DE PATILLAS BLW LAGO PATILLAS, PR',
#  'CANAL DE GUAMANI OESTE AT HWY 15 GUAYAMA, PR',
#  'RIO GUAMANI AT GUAYAMA, PR',
#  'RIO GUAMANI NR GUAYAMA, PR',
#  'QUEBRADA SECA NR GUAYAMA, PR',
#  'QUEBRADA AGUAS VERDES NR SALINAS, PR',
#  'RIO LAPA NR RABO DEL BUEY, PR',
#  'RIO MAJADA AT LA PLENA, PR',
#  'RIO COAMO AT HWY 14 AT COAMO, PR',
#  'RIO COAMO NR COAMO, PR',
#  'RIO DESCALABRADO NR LOS LLANOS, PR',
#  'RIO DESCALABRADO NR SANTA ISABEL, PR',
#  'RIO CANAS NR PASTILLO, PR',
#  'CANAL DE ACEITUNA AT VILLALBA, PR',
#  'RIO JACAGUAS ABV LAGO GUAYABAL',
#  'RIO TOA VACA ABV LAGO TOA VACA, PR',
#  'RIO TOA VACA AT HWY 150 NR VILLALBA, PR',
#  'RIO TOA VACA NR VILLALBA, PR',
#  'CANAL DE JUANA DIAZ AT PIEDRA AGUZADA NR JUANA DIA',
#  'CANAL DE JUANA DIAZ AT PASO SECO NR SANTA ISABEL',
#  'CANAL DE JUANA DIAZ AT BO. PENUELAS NR SALINAS, PR',
#  'RIO JACAGUAS AT JUANA DIAZ, PR',
#  'RIO JACAGUAS NR JUANA DIAZ, PR',
#  'RIO JACAGUAS BLW QUEBRADA GUANABANA, PR',
#  'RIO JACAGUAS AT MANZANILLO, PR',
#  'RIO INABON AT REAL ABAJO, PR',
#  'RIO CERRILLOS ABV LAGO CERRILLOS NR PONCE, PR',
#  'RIO CERRILLOS BLW LAGO CERRILLOS NR PONCE, PR',
#  'RIO BUCANA AT HWY 14 BRIDGE NR PONCE, PR',
#  'RIO BUCANA AT PLAYA DE PONCE, PR',
#  'RIO PORTUGUES NR TIBES, PR',
#  'RIO PORTUGUES NR PONCE, PR',
#  'RIO PORTUGUES BLW PORTUGUES DAMSITE, PR',
#  'RIO PORTUGUES AT PARQUE CEREMONIAL TIBES NR PONCE',
#  'RIO PORTUGUES AT HWY 14 AT PONCE, PR',
#  'RIO TALLABOA AT PENUELAS, PR',
#  'RIO TALLABOA AT HWY 127, PR',
#  'RIO GUAYANILLA NR GUAYANILLA, PR',
#  'RIO GUAYANILLA NEAR GUAYANILLA, PR',
#  'RIO GUAYANILLA AT GUAYANILLA, PR',
#  'RIO YAUCO AT LUCCHETTI DAMSITE, PR',
#  'RIO DUEY ABV DIVERSION NR YAUCO, PR',
#  'RIO YAUCO ABV DIVERSION MONSERRATE NR YAUCO, PR',
#  'RIO YAUCO AT YAUCO, PR',
#  'RIO YAUCO NR YAUCO, PR',
#  'CANAL DE RIEGO DE LAJAS BLW LAGO LOCO DAM YAUCO PR',
#  'LATERAL M5L, CANAL DE RIEGO DE LAJAS SABANA GRANDE',
#  'CANAL DE RIEGO DE LAJAS ABV MAJINAS FILT. PLANT PR',
#  'CANAL DE RIEGO DE LAJAS BLW MAJINAS FILT. PLANT PR',
#  'CANAL RIEGO DE LAJAS ABV LAJAS FILTRATION PLANT',
#  'CANAL DE RIEGO DE LAJAS BLW LAJAS FILT PLANT LAJAS',
#  'CANAL DE RIEGO DE LAJAS AT BO. PALMAREJO NR LAJAS',
#  'CANAL DE RIEGO DE LAJAS AT BO. BETANCES, PR',
#  'CANAL DE RIEGO DE LAJAS NR BOQUERON, PR',
#  'RIO LOCO NR YAUCO, PR',
#  'RIO LOCO AT LAS LATAS NR LA JOYA NR GUANICA, PR',
#  'LAJAS EAST DRAINAGE CANAL NR ENSENADA, PR',
#  'RIO LOCO NR GUANICA, PR',
#  'LAGUNA CARTAGENA OUTFLOW NR BOQUERON, PR',
#  'QUEBRADA MAMEY AT JOYUDA, PR',
#  'RIO DUEY NR ROSARIO, PR',
#  'RIO ROSARIO AT ROSARIO, PR',
#  'RIO ROSARIO NR HORMIGUEROS, PR',
#  'RIO GUANAJIBO NR HORMIGUEROS, PR',
#  'RIO BLANCO NR ADJUNTAS, PR',
#  'RIO GUAYO AT MOUTH NR LARES, PR',
#  'RIO PRIETO NR LARES, PR',
#  'RIO GRANDE DE ANASCO AT BO. GUACIO, PR',
#  'RIO GRANDE DE ANASCO NR SAN SEBASTIAN, PR',
#  'RIO GRANDE DE ANASCO AT EL ESPINO, PR',
#  'RIO CASEI ABV HACIENDA CASEI, PR',
#  'RIO CULEBRINAS AT HWY 404 NR MOCA, PR',
#  'RIO CULEBRINAS AT MARGARITA DAMSITE NR AGUADA, PR',
#  'DRAINGAGE CANAL AT CULEBRA AIRPORT, CULEBRA PR',
#  'QDA COFRESI TRIBUTARY NR ISABEL SEGUNDA VIEQUES PR',
#  'QUEBRADA LA MINA NR LA ESPERANZA, VIEQUES, PR',
#  'QUEBRADA PILON AT COLONIA PUERTO REAL, VIEQUES PR']

# %% [markdown]
# ## Request Data by County or List of Counties
# Use the [five digit FIPS code](https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/home/?cid=nrcs143_013697) for each county.

# %%
# Mills, Iowa: 19129; Maui, Hawaii: 15009
counties = hf.NWIS(countyCd = ['19129', '15009']).get_data()

# %%
counties.siteName
# Out:
# ['Keg Creek at Epperson Avenue near Glenwood, IA',
#  'Mule Creek near Malvern, IA',
#  'Spring Valley Creek near Tabor, IA',
#  'Halawa Stream near Halawa, Molokai, HI',
#  'PAPALAUA STREAM NEAR PUKOO, MOLOKAI, HI',
#  'PULENA STREAM NEAR WAILAU, MOLOKAI, HI',
#  'WAIAKEAKUA STREAM NEAR WAILAU, MOLOKAI, HI',
#  'KAPUHI STREAM NR PELEKUNU, MOLOKAI, HI',
#  'KAWAINUI STREAM NR PELEKUNU, MOLOKAI, HI',
#  'PELEKUNU STREAM NR PELEKUNU, MOLOKAI, HI',
#  'PILIPILILAU STREAM NR PELEKUNU, MOLOKAI, HI',
#  'LANIPUNI STREAM NEAR PELEKUNU, MOLOKAI, HI',
#  'Molokai Tunnel at West Portal, Molokai, HI',
#  'KEOLEWA STREAM NEAR KALAE, MOLOKAI, HI',
#  'WAIALALA SPRINGS NR KALAE, MOLOKAI, HI',
#  'Kakaako Gulch near Mauna Loa, Molokai, HI',
#  'MOKOMOKO GULCH NR KALAE, MOLOKAI, HI',
#  'KAPUNA STREAM NEAR KALAE, MOLOKAI, HI',
#  'Kaunakakai Gulch at Kaunakakai, Molokai, HI',
#  'Kaunakakai Gulch at altitude 75 feet, Molokai, HI',
#  'EF KAWELA GULCH NR KAMALO, MOLOKAI, HI',
#  'Kawela Gulch near Moku, Molokai, HI',
#  'PUNAULA GULCH NR PUKOO, MOLOKAI, HI',
#  'Papio Gulch at Halawa, Molokai, HI',
#  'Kepuni Gulch near Kahikinui House, Maui, HI',
#  'Kukuiula Gulch near Kipahulu, Maui, HI',
#  'PALIKEA STREAM BL DIV DAM NR KIPAHULU, MAUI, HI',
#  'Oheo Gulch at dam near Kipahulu, Maui, HI',
#  'HAHALAWE GULCH NEAR KIPAHULU, MAUI, HI',
#  'KAELEKU FLUME NR KAELEKU, MAUI, HI',
#  'HANA FLUME NR HANA, MAUI, HI',
#  'MAKAPIPI DITCH NEAR NAHIKU, MAUI, HI',
#  'WEST MAKAPIPI SPRING NR NAHIKU, MAUI, HI',
#  'MAKAPIPI STREAM NEAR NAHIKU, MAUI, HI',
#  'Hanawi Stream near Nahiku, Maui, HI',
#  'HANAWI STREAM BL GOVT RD NR NAHIKU, MAUI, HI',
#  'Kapaula Gulch near Nahiku, Maui, HI',
#  'KAPAULA GULCH BL GOVT RD NR NAHIKU, MAUI, HI',
#  'KOOLAU DITCH AT NAHIKU WEIR NR NAHIKU, MAUI, HI',
#  'Waiaka Stream near Nahiku, Maui, HI',
#  'PAAKEA GULCH NEAR NAHIKU, MAUI, HI',
#  'Waiohue Gulch near Nahiku, Maui, HI',
#  'Kopiliula Stream near Keanae, Maui, HI',
#  'East Wailuaiki Stream near Keanae, Maui, HI',
#  'West Wailuaiki Stream near Keanae, Maui, HI',
#  'WEST WAILUANUI STREAM NEAR KEANAE, MAUI, HI',
#  'East Wailuanui Stream near Keanae, Maui, HI',
#  'Wailuanui Stream near Keanae, Maui, HI',
#  'Waiokamilo Stream at Dam 3 near Keanae, Maui, HI',
#  'TARO PATCH FEEDER DITCH AT KEANAE, MAUI, HI',
#  'Koolau Ditch near Keanae, Maui, HI',
#  'HONOMANU STR AT HAIKU-UKA BDRY NR KAILIILI,MAUI',
#  'Honomanu Stream near Keanae, Maui, HI',
#  'KULA DIV FROM HAIPUAENA STR NR OLINDA,MAUI,HI',
#  'HAIPUAENA STREAM AT KULA DIVERSION',
#  'HAIPUAENA STR AT KULA PL INTK NR OLINDA,MAUI,HI',
#  'HAIPUAENA STR AT HAIKU-UKA BDY NR KAILIILI, MAUI',
#  'HAIPUAENA DIV DITCH AT KOLEA GL NR KEANAE, MAUI',
#  'HAIPUAENA STR AB SPRECKELS DITCH NR HUELO, MAUI',
#  'SPRECKELS DITCH AT HAIPUAENA WEIR NR HUELO, MAUI',
#  'KOOLAU DITCH AT HAIPUAENA NR HUELO, MAUI, HI',
#  'Manuel Luis Ditch at Puohokamoa Stream, Maui, HI',
#  'E B PUOHOKAMOA STR AT HAIKU-UKA BDRY NR KAILIILI',
#  'M B PUOHOKAMOA STR AT HAIKU-UKA BDRY NR KAILIILI',
#  'W B PUOHOKAMOA STR AT HAIKU-UKA BDRY NR KAILIILI',
#  'PUOHOKAMOA STR AB SPRECKELS DITCH NR HUELO, MAUI',
#  'KOOLAU DITCH AT WAHINEPEE NR HUELO, MAUI, HI',
#  'SPRECKELS DITCH AT WAHINEPEE NR HUELO, MAUI, HI',
#  'MANUEL LUIS DI W OF PUOHOKAMOA STR NR HUELO,MAUI',
#  'Waikamoi Stream at Puu Luau nr Olinda, Maui, HI',
#  'Waikamoi Str abv Kula PL intake nr Olinda, Maui,HI',
#  'WAIKAMOI STR AT HAIKU-UKA BDRY NR KAILIILI, MAUI',
#  'E BR WAIKAMOI STR AT HAIKU-UKA BDRY NR KAILIILI',
#  'WAIKAMOI STR AB WAILOA DITCH NR HUELO, MAUI,HI',
#  'WAIKAMOI STREAM NEAR HUELO, MAUI, HI',
#  'ALO STREAM NEAR HUELO, MAUI, HI',
#  'CENTER DITCH BELOW KOLEA RESERVOIR NR HUELO,MAUI',
#  'KAAIEA GULCH NEAR HUELO, MAUI, HI',
#  'SPRECKELS DITCH BELOW KAAIEA GULCH NR HUELO,MAUI',
#  'OOPUOLA STREAM NEAR HUELO, MAUI, HI',
#  'OOPUOLA STR AB SPRECKELS DITCH CRSNG NR HUELO,MA',
#  'Nailiilihaele Stream near Huelo, Maui, HI',
#  'KAILUA STR AT HAIKU-UKA BDRY NR KAILIILI,MAUI,HI',
#  'KAILUA STREAM NR KAILIILI, MAUI, HI',
#  'Kailua Stream near Huelo, Maui, HI',
#  'NEW HAMAKUA DITCH AT STATION 5 NR HUELO,MAUI,HI',
#  'HOOLAWANUI STREAM NR HUELO, MAUI, HI',
#  'HOOLAWALIILII STREAM NEAR HUELO, MAUI, HI',
#  'Honopou Stream near Huelo, Maui, HI',
#  'Wailoa Ditch at Honopou near Huelo, Maui, HI',
#  'New Hamakua Ditch at Honopou near Huelo, Maui, HI',
#  'OLD HAMAKUA DITCH AT HONOPOU NR HUELO, MAUI,HI',
#  'HONOPOU STR AT LOWRIE DITCH SIPHON NR HUELO,MAUI',
#  'Lowrie Ditch at Honopou Gulch near Huelo, Maui, HI',
#  'HONOPOU STR AB HAIKU DITCH NR HUELO, MAUI, HI',
#  'Haiku Ditch at Honopou Gulch near Kailua, Maui, HI',
#  'HONOPOU STR BELOW HAIKU DITCH NR HUELO,MAUI,HI',
#  'Div. Ditch at intake, Honopou Str nr Huelo,Maui,HI',
#  'Honopou Stream blw. div. ditch nr Huelo, Maui, HI',
#  'NEW HAMAKUA DITCH AT HALEHAKU WEIR NR HUELO,MAUI',
#  'Halehaku Gulch near Kailiili, Maui, HI',
#  'Opana Tunnel near Kailiili, Maui, HI',
#  'KAUHIKOA DITCH AT OPANA WEIR NR HUELO, MAUI, HI',
#  'AWALAU GULCH AT KAILIILI, MAUI, HI',
#  'Wailuku River at Kepaniwai Park, Maui, HI',
#  'SOUTH WAIEHU STREAM NR WAILUKU, MAUI, HI',
#  'WAIHEE RIVER NR WAIHEE, MAUI, HI',
#  'Waihee Rv abv Waihee Dtch intk nr Waihee, Maui, HI',
#  'LEFT BR MAKAMAKAOLE STREAM NR WAIHEE, MAUI, HI',
#  'Kahakuloa Stream near Honokohau, Maui, HI',
#  'Honokohau Stream near Honokohau, Maui, HI',
#  'HONOKOHAU DITCH AT INTAKE NR HONOKOHAU, MAUI, HI',
#  'Honolua Stream nr Honokohau, Maui, HI',
#  'HONOKOWAI DITCH NEAR LAHAINA, MAUI, HI',
#  'HONOKOWAI STREAM NR LAHAINA, MAUI, HI',
#  'Kahoma Development Tunnel nr Lahaina, Maui, HI',
#  'KAHOMA STREAM NR LAHAINA, MAUI, HI',
#  'Kanaha Stream ab PL Intake nr Lahaina, Maui, HI',
#  'KANAHA STREAM NR LAHAINA, MAUI, HI',
#  'Kahoma Stream at Lahaina, Maui, HI',
#  'KAUAULA STREAM NR LAHAINA, MAUI, HI',
#  'Kauaula Ditch nr Lahaina, Maui, HI',
#  'LAUNIUPOKO STREAM NR LAHAINA, MAUI, HI',
#  'OLOWALU DITCH NEAR OLOWALU, MAUI, HI',
#  'Olowalu Stream at Olowalu, Maui, HI',
#  'Ukumehame Gulch nr Olowalu, Maui, HI',
#  'SOUTH SIDE WAIKAPU DITCH NR WAIKAPU, MAUI, HI',
#  'PALOLO DITCH NR WAIKAPU, MAUI, HI',
#  'Kulanihakoi Gulch near Kihei, Maui, HI',
#  'Hakioawa Gulch at alt. 75 ft, Kahoolawe, HI',
#  'Kaulana Gulch at alt. 100 ft, Kahoolawe, HI']

# %% [markdown]
# ## Request data using a bounding box.
# The coordinates for the bounding box should be in decimal degrees, with negative values for Western and Southern hemispheres.
# Give the coordinates counter clockwise: West, South, East, North

# %%
# Request multiple sites using a bounding box
test = hf.NWIS(bBox=[-105.430, 39.655, -104, 39.863]).get_data()
test.response.ok
# Out:
# True

# %%
test.name
# Out:
# ['USGS:06711565:00060:00003',
#  'USGS:06711570:00060:00003',
#  'USGS:06711575:00060:00003',
#  'USGS:06711590:00060:00003',
#  'USGS:06711618:00060:00003',
#  'USGS:06711770:00060:00003',
#  'USGS:06711780:00060:00003',
#  'USGS:06713300:00060:00003',
#  'USGS:06713500:00060:00003',
#  'USGS:06714000:00060:00003',
#  'USGS:06714100:00060:00003',
#  'USGS:06714130:00060:00003',
#  'USGS:06714215:00060:00003',
#  'USGS:06714360:00060:00003',
#  'USGS:06718500:00060:00003',
#  'USGS:06718550:00060:00003',
#  'USGS:06719000:00060:00003',
#  'USGS:06719500:00060:00003',
#  'USGS:06719505:00060:00003',
#  'USGS:06719526:00060:00003',
#  'USGS:06719560:00060:00003',
#  'USGS:06719725:00060:00003',
#  'USGS:06719735:00060:00003',
#  'USGS:06719740:00060:00003',
#  'USGS:06719840:00060:00003',
#  'USGS:06720000:00060:00003',
#  'USGS:06720255:00060:00003',
#  'USGS:06720280:00060:00003',
#  'USGS:06720285:00060:00003',
#  'USGS:06720460:00060:00003',
#  'USGS:06758300:00060:00003',
#  'USGS:394329104490101:00060:00003',
#  'USGS:394839104570300:00060:00003']

# %%
import pandas as pd
import numpy as np

# %%
import hydrofunctions as hf

# %%
start = "2014-05-01"
end = "2014-06-01"
one = hf.NWIS("01585200", "dv", start, end)
two = hf.NWIS("01583800", "iv", start, end)

# %%
two.response
# Out:
# <Response [200]>

# %%
one.df
# Out:
#             value
# datetime
# 2014-05-01   12.0
# 2014-05-02    4.9
# 2014-05-03    3.6
# 2014-05-04    3.4
# 2014-05-05    3.1
# 2014-05-06    2.5
# 2014-05-07    3.0
# 2014-05-08    2.3
# 2014-05-09    2.2
# 2014-05-10    2.9
# 2014-05-11    2.3
# 2014-05-12    2.1
# 2014-05-13    2.0
# 2014-05-14    2.1
# 2014-05-15    2.2
# 2014-05-16   34.0
# 2014-05-17    2.9
# 2014-05-18    2.3
# 2014-05-19    2.1
# 2014-05-20    2.0
# 2014-05-21    2.6
# 2014-05-22    3.3
# 2014-05-23    1.8
# 2014-05-24    1.7
# 2014-05-25    1.6
# 2014-05-26    1.5
# 2014-05-27    9.2
# 2014-05-28    3.0
# 2014-05-29    5.8
# 2014-05-30    2.2
# 2014-05-31    1.6
# 2014-06-01    1.4

# %%
one.df.dtypes
# Out:
# value    float64
# dtype: object

# %%
one.df.max()
# Out:
# value    34.0
# dtype: float64

# %%
dir(one)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'dataframe',
#  'df',
#  'end_date',
#  'fetchNWIS',
#  'id',
#  'json',
#  'response',
#  'service',
#  'start_date',
#  'station_dict']

# %%
dir(one.df)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
# ...

# %%
one.df.mean()
# Out:
# value    4.05
# dtype: float64

# %%
two.df.mean()
# Out:
# value    4.596041
# dtype: float64

# %%
one.dataframe()

# %%
1 < "string"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-0c45e917b37d> in <module>()
# ----> 1 1 < "string"
#
# TypeError: unorderable types: int() < str()

# %% [markdown]
# ### Break Python 3:
# Use the old-fashioned print statement  `print "hello"`  to check if you are using Python 2 or 3.

# %%
print "hello"
# Out:
# hello

# %%
print("hello")
# Out:
# hello

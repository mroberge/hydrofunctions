# %%
# %matplotlib inline
import hydrofunctions as hf

# %% [markdown]
# ### Get data for a streamflow gage

# %%
start = "2013-01-01"
end = "2013-02-01"
first = hf.NWIS("01638500", "dv", start, end)

# %%
first.json()
# Out:
# You must call .get_data() before calling .json().

# %%
first.df()
# Out:
# You must call .get_data() before calling .df().

# %%
first.get_data()

# %%
first.df().max()
# Out:
# 01638500 - Mean Discharge, cubic feet per second    73900.0
# dtype: float64

# %% [markdown]
# #### Plot the data for a stream gage

# %%
first.df().plot()

# %% [markdown]
# ### Get data for a second gage

# %%
second = hf.NWIS("01585200", "dv", "2014-05-01", "2014-05-03")

# %%
second.get_data().df().mean()
# Out:
# 01585200 - Mean Discharge, cubic feet per second    6.933333
# dtype: float64

# %% [markdown]
# #### Plot the data for the second gage

# %%
second.df().plot()

# %%
sites = ['07227500', '07228000', '07233500', '07235000', '07295500', '07297910', '07298500', '07299540',
         '07299670', '07299890', '07300000', '07301300', '07301410', '07308200', '07308500', '07311600',
         '07311630', '07311700', '07311782', '07311783', '07311800', '07311900', '07312100', '07312200',
         '07312500', '07312700', '07314500', '07314900', '07315200', '07315500', '07342465', '07342480',
         '07342500', '07343000', '07343200', '07343500', '07344210', '07344500', '07346000']
mult = hf.NWIS(sites, "dv", "2018-01-01", "2018-01-31")
print('No. sites: {}'.format(len(sites)))
mult.get_data().df().mean()
# Out:
# No. sites: 39
# 07228000 - Mean Discharge, cubic feet per second         57.848387
# 07227500 - Mean Discharge, cubic feet per second         52.237931
# 07233500 - Maximum Discharge, cubic feet per second       0.019286
# 07233500 - Minimum Discharge, cubic feet per second       0.000000
# 07233500 - Mean Discharge, cubic feet per second          0.001071
# 07235000 - Maximum Discharge, cubic feet per second       0.548065
# 07235000 - Minimum Discharge, cubic feet per second       0.351613
# 07235000 - Mean Discharge, cubic feet per second          0.443548
# 07295500 - Maximum Discharge, cubic feet per second       0.000000
# 07295500 - Minimum Discharge, cubic feet per second       0.000000
# 07295500 - Mean Discharge, cubic feet per second          0.000000
# 07297910 - Maximum Discharge, cubic feet per second      23.683333
# 07297910 - Minimum Discharge, cubic feet per second      15.070833
# 07297910 - Mean Discharge, cubic feet per second         18.975000
# 07298500 - Maximum Discharge, cubic feet per second      12.223226
# 07298500 - Minimum Discharge, cubic feet per second       8.869677
# 07298500 - Mean Discharge, cubic feet per second         10.689032
# 07299540 - Mean Discharge, cubic feet per second         24.940000
# 07299670 - Maximum Discharge, cubic feet per second      10.751290
# 07299670 - Minimum Discharge, cubic feet per second       9.531613
# 07299670 - Mean Discharge, cubic feet per second         10.071935
# 07299890 - Maximum Discharge, cubic feet per second       1.062000
# 07299890 - Minimum Discharge, cubic feet per second       0.683000
# 07299890 - Mean Discharge, cubic feet per second          0.807000
# 07300000 - Mean Discharge, cubic feet per second         17.880645
# 07301300 - Mean Discharge, cubic feet per second         22.967742
# 07301410 - Maximum Discharge, cubic feet per second       5.318571
# 07301410 - Minimum Discharge, cubic feet per second       4.074286
# 07301410 - Mean Discharge, cubic feet per second          4.732857
# 07308200 - Mean Discharge, cubic feet per second         18.525000
#                                                           ...
# 07315500 - Maximum Discharge, cubic feet per second     495.967742
# 07315500 - Minimum Discharge, cubic feet per second     452.290323
# 07315500 - Mean Discharge, cubic feet per second        475.193548
# 07342465 - Maximum Discharge, cubic feet per second       9.104516
# 07342465 - Minimum Discharge, cubic feet per second       1.122581
# 07342465 - Mean Discharge, cubic feet per second          3.414194
# 07342480 - Maximum Discharge, cubic feet per second       1.872581
# 07342480 - Minimum Discharge, cubic feet per second       0.301613
# 07342480 - Mean Discharge, cubic feet per second          1.100645
# 07342500 - Maximum Discharge, cubic feet per second       6.545484
# 07342500 - Minimum Discharge, cubic feet per second       5.444516
# 07342500 - Mean Discharge, cubic feet per second          5.900323
# 07343000 - Maximum Discharge, cubic feet per second      60.247419
# 07343000 - Minimum Discharge, cubic feet per second      12.233548
# 07343000 - Mean Discharge, cubic feet per second         30.565161
# 07343200 - Maximum Discharge, cubic feet per second            NaN
# 07343200 - Minimum Discharge, cubic feet per second            NaN
# 07343200 - Mean Discharge, cubic feet per second         77.741935
# 07343500 - Maximum Discharge, cubic feet per second      56.606667
# 07343500 - Minimum Discharge, cubic feet per second      37.333333
# 07343500 - Mean Discharge, cubic feet per second         46.816667
# 07344210 - Maximum Discharge, cubic feet per second    1401.461538
# 07344210 - Minimum Discharge, cubic feet per second    1307.000000
# 07344210 - Mean Discharge, cubic feet per second               NaN
# 07344500 - Maximum Discharge, cubic feet per second      10.533871
# 07344500 - Minimum Discharge, cubic feet per second       6.183548
# 07344500 - Mean Discharge, cubic feet per second          8.130323
# 07346000 - Maximum Discharge, cubic feet per second     287.129032
# 07346000 - Minimum Discharge, cubic feet per second     283.193548
# 07346000 - Mean Discharge, cubic feet per second        285.000000
# Length: 79, dtype: float64

# %%
mult.get_data().df()['07228000 - Mean Discharge, cubic feet per second'].plot()

# %% [markdown]
# ### Get individual value (`iv`) data for a groundwater well

# %%
third = hf.NWIS(["380616075380701","394008077005601"], "iv", "2018-01-01", "2018-01-31", parameterCd='72019')

# %%
third.get_data().df().mean()
# Out:
# 380616075380701 -  Depth to water level, feet below land surface    1.215141
# 394008077005601 -  Depth to water level, feet below land surface    3.205391
# dtype: float64

# %% [markdown]
# #### Plot the individual value data for a groundwater well

# %%
third.df().plot(marker='o', mfc='white', ms=4, mec='black', color='black')

# %% [markdown]
# ### Download discharge data for two stations

# %%
start = "2013-01-01"
end = "2014-12-31"
sites = ["01638500", "01646502"]
test = hf.get_nwis(sites, "dv", start, end)
actual = hf.extract_nwis_df(test)

# %%
actual.columns
# Out:
# Index(['01638500 - Mean Discharge, cubic feet per second', '01646502 - Mean Discharge, cubic feet per second'], dtype='object')

# %% [markdown]
# #### Create a table of discharge data

# %%
actual
# Out:
#             01638500 - Mean Discharge, cubic feet per second  \
# 2013-01-01                                            8540.0
# 2013-01-02                                            8280.0
# 2013-01-03                                            8240.0
# 2013-01-04                                            8100.0
# 2013-01-05                                            7720.0
# 2013-01-06                                            7360.0
# 2013-01-07                                            7040.0
# 2013-01-08                                            7010.0
# 2013-01-09                                            7300.0
# 2013-01-10                                            7450.0
# 2013-01-11                                            7460.0
# 2013-01-12                                            8310.0
# 2013-01-13                                           11700.0
# 2013-01-14                                           15100.0
# 2013-01-15                                           17600.0
# 2013-01-16                                           20300.0
# 2013-01-17                                           34200.0
# 2013-01-18                                           39000.0
# 2013-01-19                                           30600.0
# 2013-01-20                                           23800.0
# 2013-01-21                                           19900.0
# 2013-01-22                                           17000.0
# 2013-01-23                                           13800.0
# 2013-01-24                                           11000.0
# 2013-01-25                                            9240.0
# 2013-01-26                                            7980.0
# 2013-01-27                                            7550.0
# 2013-01-28                                            7510.0
# 2013-01-29                                            7840.0
# 2013-01-30                                            9460.0
# ...                                                      ...
# 2014-12-02                                            3740.0
# 2014-12-03                                            4190.0
# 2014-12-04                                            5310.0
# 2014-12-05                                            6970.0
# 2014-12-06                                            7320.0
# 2014-12-07                                            8590.0
# 2014-12-08                                           12600.0
# 2014-12-09                                           14500.0
# 2014-12-10                                           14100.0
# 2014-12-11                                           13000.0
# 2014-12-12                                           11100.0
# 2014-12-13                                            9690.0
# 2014-12-14                                            8530.0
# 2014-12-15                                            7580.0
# 2014-12-16                                            6920.0
# 2014-12-17                                            6580.0
# 2014-12-18                                            5860.0
# 2014-12-19                                            5330.0
# 2014-12-20                                            5110.0
# 2014-12-21                                            4900.0
# 2014-12-22                                            4730.0
# 2014-12-23                                            4750.0
# 2014-12-24                                            5350.0
# 2014-12-25                                            6040.0
# 2014-12-26                                            7830.0
# 2014-12-27                                            8140.0
# 2014-12-28                                            7570.0
# 2014-12-29                                            6880.0
# 2014-12-30                                            6300.0
# 2014-12-31                                            5920.0
#
#             01646502 - Mean Discharge, cubic feet per second
# 2013-01-01                                           11100.0
# 2013-01-02                                           10600.0
# 2013-01-03                                           10200.0
# 2013-01-04                                            9990.0
# 2013-01-05                                            9520.0
# 2013-01-06                                            9030.0
# 2013-01-07                                            8630.0
# 2013-01-08                                            8370.0
# 2013-01-09                                            8500.0
# 2013-01-10                                            8650.0
# 2013-01-11                                            8650.0
# 2013-01-12                                            8810.0
# 2013-01-13                                           10800.0
# 2013-01-14                                           14200.0
# 2013-01-15                                           17500.0
# 2013-01-16                                           23800.0
# 2013-01-17                                           37900.0
# 2013-01-18                                           48000.0
# 2013-01-19                                           40400.0
# 2013-01-20                                           30400.0
# 2013-01-21                                           24400.0
# 2013-01-22                                           20600.0
# 2013-01-23                                           17000.0
# 2013-01-24                                           13900.0
# 2013-01-25                                           11700.0
# 2013-01-26                                            9950.0
# 2013-01-27                                            9460.0
# 2013-01-28                                            9300.0
# 2013-01-29                                            9420.0
# 2013-01-30                                            9650.0
# ...                                                      ...
# 2014-12-02                                            5410.0
# 2014-12-03                                            5900.0
# 2014-12-04                                            6310.0
# 2014-12-05                                            7720.0
# 2014-12-06                                            8700.0
# 2014-12-07                                           10500.0
# 2014-12-08                                           14100.0
# 2014-12-09                                           17700.0
# 2014-12-10                                           20100.0
# 2014-12-11                                           18100.0
# 2014-12-12                                           14800.0
# 2014-12-13                                           12400.0
# 2014-12-14                                           10800.0
# 2014-12-15                                            9450.0
# 2014-12-16                                            8830.0
# 2014-12-17                                            8560.0
# 2014-12-18                                            7940.0
# 2014-12-19                                            7030.0
# 2014-12-20                                            6400.0
# 2014-12-21                                            6130.0
# 2014-12-22                                            5910.0
# 2014-12-23                                            5950.0
# 2014-12-24                                            7990.0
# 2014-12-25                                           12100.0
# 2014-12-26                                           11600.0
# 2014-12-27                                           10900.0
# 2014-12-28                                           10100.0
# 2014-12-29                                            9250.0
# 2014-12-30                                            8340.0
# 2014-12-31                                            7650.0
#
# [730 rows x 2 columns]

# %% [markdown]
# #### Plot discharge data for two stations

# %%
actual.plot()

# %% [markdown]
# ### Download stage data for two stations

# %%
start = "2013-01-01"
end = "2014-12-31"
sites = ["01644148", "01651750"]
test = hf.get_nwis(sites, "dv", start, end, parameterCd='00065')
actual = hf.extract_nwis_df(test)

# %%
actual
# Out:
#             01644148 - Maximum Gage height, feet  \
# 2013-01-01                                  5.97
# 2013-01-02                                  5.82
# 2013-01-03                                  5.75
# 2013-01-04                                  5.68
# 2013-01-05                                  5.58
# 2013-01-06                                  5.44
# 2013-01-07                                  5.34
# 2013-01-08                                  5.27
# 2013-01-09                                  5.33
# 2013-01-10                                  5.34
# 2013-01-11                                  5.34
# 2013-01-12                                  5.73
# 2013-01-13                                  6.60
# 2013-01-14                                  7.22
# 2013-01-15                                  7.76
# 2013-01-16                                 10.03
# 2013-01-17                                 11.93
# 2013-01-18                                 12.12
# 2013-01-19                                 11.46
# 2013-01-20                                  9.92
# 2013-01-21                                  8.86
# 2013-01-22                                  8.14
# 2013-01-23                                  7.48
# 2013-01-24                                  6.78
# 2013-01-25                                  6.20
# 2013-01-26                                  5.81
# 2013-01-27                                  5.59
# 2013-01-28                                  5.54
# 2013-01-29                                  5.55
# 2013-01-30                                  9.30
# ...                                          ...
# 2014-12-02                                  4.12
# 2014-12-03                                  4.41
# 2014-12-04                                  4.89
# 2014-12-05                                  5.16
# 2014-12-06                                  5.30
# 2014-12-07                                  6.38
# 2014-12-08                                  6.95
# 2014-12-09                                  7.61
# 2014-12-10                                  7.68
# 2014-12-11                                  7.51
# 2014-12-12                                  6.81
# 2014-12-13                                  6.29
# 2014-12-14                                  5.89
# 2014-12-15                                  5.55
# 2014-12-16                                  5.28
# 2014-12-17                                  5.17
# 2014-12-18                                  5.07
# 2014-12-19                                  4.80
# 2014-12-20                                  4.61
# 2014-12-21                                  4.54
# 2014-12-22                                  4.43
# 2014-12-23                                  4.43
# 2014-12-24                                  5.72
# 2014-12-25                                  6.24
# 2014-12-26                                  5.95
# 2014-12-27                                  5.81
# 2014-12-28                                  5.63
# 2014-12-29                                  5.40
# 2014-12-30                                  5.16
# 2014-12-31                                  4.96
#
#             01644148 - Minimum Gage height, feet  \
# 2013-01-01                                  5.82
# 2013-01-02                                  5.75
# 2013-01-03                                  5.68
# 2013-01-04                                  5.58
# 2013-01-05                                  5.44
# 2013-01-06                                  5.34
# 2013-01-07                                  5.25
# 2013-01-08                                  5.23
# 2013-01-09                                  5.27
# 2013-01-10                                  5.31
# 2013-01-11                                  5.30
# 2013-01-12                                  5.34
# 2013-01-13                                  5.73
# 2013-01-14                                  6.60
# 2013-01-15                                  7.22
# 2013-01-16                                  7.76
# 2013-01-17                                 10.03
# 2013-01-18                                 11.46
# 2013-01-19                                  9.92
# 2013-01-20                                  8.86
# 2013-01-21                                  8.14
# 2013-01-22                                  7.48
# 2013-01-23                                  6.78
# 2013-01-24                                  6.20
# 2013-01-25                                  5.81
# 2013-01-26                                  5.55
# 2013-01-27                                  5.50
# 2013-01-28                                  5.48
# 2013-01-29                                  5.52
# 2013-01-30                                  5.53
# ...                                          ...
# 2014-12-02                                  4.04
# 2014-12-03                                  4.12
# 2014-12-04                                  4.41
# 2014-12-05                                  4.89
# 2014-12-06                                  5.16
# 2014-12-07                                  5.30
# 2014-12-08                                  6.38
# 2014-12-09                                  6.95
# 2014-12-10                                  7.51
# 2014-12-11                                  6.81
# 2014-12-12                                  6.29
# 2014-12-13                                  5.89
# 2014-12-14                                  5.55
# 2014-12-15                                  5.28
# 2014-12-16                                  5.15
# 2014-12-17                                  5.07
# 2014-12-18                                  4.80
# 2014-12-19                                  4.61
# 2014-12-20                                  4.54
# 2014-12-21                                  4.43
# 2014-12-22                                  4.35
# 2014-12-23                                  4.35
# 2014-12-24                                  4.42
# 2014-12-25                                  5.72
# 2014-12-26                                  5.81
# 2014-12-27                                  5.63
# 2014-12-28                                  5.40
# 2014-12-29                                  5.16
# 2014-12-30                                  4.96
# 2014-12-31                                  4.80
#
#             01651750 - Tidal High-High Gage height, feet  \
# 2013-01-01                                          0.75
# 2013-01-02                                          1.15
# 2013-01-03                                          1.64
# 2013-01-04                                          1.22
# 2013-01-05                                          0.81
# 2013-01-06                                          1.18
# 2013-01-07                                          1.04
# 2013-01-08                                          1.71
# 2013-01-09                                          1.75
# 2013-01-10                                          1.41
# 2013-01-11                                          1.58
# 2013-01-12                                          2.16
# 2013-01-13                                          2.76
# 2013-01-14                                          2.61
# 2013-01-15                                          2.12
# 2013-01-16                                          2.55
# 2013-01-17                                          2.57
# 2013-01-18                                          2.13
# 2013-01-19                                          2.19
# 2013-01-20                                          1.83
# 2013-01-21                                          1.32
# 2013-01-22                                          0.63
# 2013-01-23                                          0.86
# 2013-01-24                                          1.08
# 2013-01-25                                          1.39
# 2013-01-26                                          1.02
# 2013-01-27                                          1.77
# 2013-01-28                                          1.82
# 2013-01-29                                          1.60
# 2013-01-30                                          2.82
# ...                                                  ...
# 2014-12-02                                          1.49
# 2014-12-03                                          2.48
# 2014-12-04                                          2.06
# 2014-12-05                                          1.81
# 2014-12-06                                          2.25
# 2014-12-07                                          1.22
# 2014-12-08                                          2.71
# 2014-12-09                                          2.22
# 2014-12-10                                          1.70
# 2014-12-11                                          1.39
# 2014-12-12                                          0.64
# 2014-12-13                                          1.33
# 2014-12-14                                          1.79
# 2014-12-15                                          1.98
# 2014-12-16                                          2.39
# 2014-12-17                                          1.89
# 2014-12-18                                          1.33
# 2014-12-19                                          0.75
# 2014-12-20                                          1.56
# 2014-12-21                                          2.02
# 2014-12-22                                          2.15
# 2014-12-23                                          2.36
# 2014-12-24                                          3.14
# 2014-12-25                                          2.60
# 2014-12-26                                          1.69
# 2014-12-27                                          1.35
# 2014-12-28                                          1.57
# 2014-12-29                                          1.42
# 2014-12-30                                          1.72
# 2014-12-31                                          1.83
#
#             01651750 - Tidal Low-Low Gage height, feet
# 2013-01-01                                       -1.93
# 2013-01-02                                       -2.24
# 2013-01-03                                       -1.42
# 2013-01-04                                       -1.73
# 2013-01-05                                       -2.04
# 2013-01-06                                       -2.02
# 2013-01-07                                       -1.87
# 2013-01-08                                       -1.38
# 2013-01-09                                       -1.61
# 2013-01-10                                       -2.06
# 2013-01-11                                       -2.06
# 2013-01-12                                       -1.87
# 2013-01-13                                       -1.33
# 2013-01-14                                       -1.00
# 2013-01-15                                       -1.20
# 2013-01-16                                       -0.51
# 2013-01-17                                       -0.20
# 2013-01-18                                       -0.65
# 2013-01-19                                       -0.13
# 2013-01-20                                       -1.70
# 2013-01-21                                       -1.88
# 2013-01-22                                       -1.83
# 2013-01-23                                       -1.59
# 2013-01-24                                       -1.77
# 2013-01-25                                       -1.97
# 2013-01-26                                       -1.70
# 2013-01-27                                       -1.67
# 2013-01-28                                       -1.26
# 2013-01-29                                       -1.61
# 2013-01-30                                       -1.33
# ...                                                ...
# 2014-12-02                                       -1.65
# 2014-12-03                                       -0.75
# 2014-12-04                                       -1.33
# 2014-12-05                                       -1.51
# 2014-12-06                                       -1.46
# 2014-12-07                                       -2.09
# 2014-12-08                                       -1.37
# 2014-12-09                                       -0.60
# 2014-12-10                                       -0.98
# 2014-12-11                                       -1.00
# 2014-12-12                                       -2.23
# 2014-12-13                                       -1.50
# 2014-12-14                                       -0.92
# 2014-12-15                                       -0.74
# 2014-12-16                                       -0.48
# 2014-12-17                                       -1.07
# 2014-12-18                                       -1.85
# 2014-12-19                                       -2.17
# 2014-12-20                                       -2.14
# 2014-12-21                                       -1.70
# 2014-12-22                                       -1.49
# 2014-12-23                                       -1.47
# 2014-12-24                                       -0.93
# 2014-12-25                                       -0.99
# 2014-12-26                                       -1.67
# 2014-12-27                                       -1.90
# 2014-12-28                                       -1.70
# 2014-12-29                                       -1.79
# 2014-12-30                                       -1.59
# 2014-12-31                                       -1.37
#
# [730 rows x 4 columns]

# %% [markdown]
# #### Plot stage data for two stations

# %%
actual.plot()

# %% [markdown]
# ### Download groundwater data for two stations

# %%
start = "2013-01-01"
end = "2014-12-31"
sites = ["385638077220101", "390623077314201"]
test = hf.get_nwis(sites, "dv", start, end, parameterCd='72019')
actual = hf.extract_nwis_df(test)

# %% [markdown]
# #### Plot maximum and minimum groundwater data for two stations

# %%
actual.plot()

# %% [markdown]
# ### Download all streamflow data for the state of Virginia

# %%
start = "2017-01-01"
end = "2017-12-31"
vas = hf.get_nwis(None, "dv", start, end, stateCd='va')

# %%
vad = hf.extract_nwis_df(vas)

# %%
vad.mean()
# Out:
# 01613900 - Mean Discharge, cubic feet per second      12.851436
# 01615000 - Mean Discharge, cubic feet per second      41.876453
# 01616100 - Mean Discharge, cubic feet per second       8.948493
# 01620500 - Mean Discharge, cubic feet per second      17.857973
# 01621050 - Mean Discharge, cubic feet per second       3.844548
# 01622000 - Mean Discharge, cubic feet per second     280.384932
# 01625000 - Mean Discharge, cubic feet per second     245.340548
# 01626000 - Mean Discharge, cubic feet per second     106.207123
# 01626850 - Mean Discharge, cubic feet per second     143.052603
# 01627500 - Mean Discharge, cubic feet per second     186.330556
# 01628500 - Mean Discharge, cubic feet per second     754.451524
# 01629500 - Mean Discharge, cubic feet per second     994.933884
# 01631000 - Mean Discharge, cubic feet per second    1123.279778
# 01632000 - Mean Discharge, cubic feet per second     124.048740
# 01632082 - Mean Discharge, cubic feet per second      17.520329
# 01632900 - Mean Discharge, cubic feet per second      39.437729
# 01633000 - Mean Discharge, cubic feet per second     218.096712
# 01634000 - Mean Discharge, cubic feet per second     367.323810
# 01634500 - Mean Discharge, cubic feet per second      77.223726
# 01635500 - Mean Discharge, cubic feet per second      49.117591
# 01636316 - Mean Discharge, cubic feet per second      16.260986
# 01636690 - Mean Discharge, cubic feet per second      11.950361
# 01638350 - Mean Discharge, cubic feet per second      25.395694
# 01638420 - Mean Discharge, cubic feet per second      19.307179
# 01638480 - Mean Discharge, cubic feet per second      66.803562
# 01643590 - Mean Discharge, cubic feet per second       5.084121
# 01643700 - Mean Discharge, cubic feet per second      99.034521
# 01643805 - Mean Discharge, cubic feet per second      31.569972
# 01643880 - Mean Discharge, cubic feet per second      42.864721
# 01644000 - Mean Discharge, cubic feet per second     271.511233
#                                                        ...
# 02077000 - Mean Discharge, cubic feet per second     496.727945
# 02079640 - Mean Discharge, cubic feet per second      31.207562
# 03164000 - Mean Discharge, cubic feet per second    1811.813699
# 03165000 - Mean Discharge, cubic feet per second      69.262431
# 03165500 - Mean Discharge, cubic feet per second    2116.475275
# 03167000 - Mean Discharge, cubic feet per second     270.208310
# 03168000 - Mean Discharge, cubic feet per second    3159.178082
# 03170000 - Mean Discharge, cubic feet per second     367.142857
# 03171000 - Mean Discharge, cubic feet per second    3966.383562
# 03173000 - Mean Discharge, cubic feet per second     335.351781
# 03175500 - Mean Discharge, cubic feet per second     321.513973
# 03176500 - Mean Discharge, cubic feet per second    5021.671233
# 03177710 - Mean Discharge, cubic feet per second      63.100826
# 03207800 - Mean Discharge, cubic feet per second     385.678904
# 03208500 - Mean Discharge, cubic feet per second     331.220330
# 03208950 - Mean Discharge, cubic feet per second      85.311295
# 03209000 - Mean Discharge, cubic feet per second     294.153973
# 03209200 - Mean Discharge, cubic feet per second            NaN
# 03471500 - Mean Discharge, cubic feet per second     109.356712
# 03473000 - Mean Discharge, cubic feet per second     501.227123
# 03474000 - Mean Discharge, cubic feet per second     171.507123
# 03475000 - Mean Discharge, cubic feet per second     254.800822
# 03478400 - Mean Discharge, cubic feet per second      34.246301
# 03488000 - Mean Discharge, cubic feet per second     296.787945
# 03490000 - Mean Discharge, cubic feet per second     880.667403
# 03524000 - Mean Discharge, cubic feet per second     700.853151
# 03524500 - Mean Discharge, cubic feet per second     143.473973
# 03527000 - Mean Discharge, cubic feet per second    1510.515068
# 03529500 - Mean Discharge, cubic feet per second     187.787397
# 03531500 - Mean Discharge, cubic feet per second     554.865479
# Length: 187, dtype: float64

# %% [markdown]
# #### Plot all streamflow data for the state of Virginia

# %%
vad.plot(legend=None)

# %% [markdown]
# ### Download all streamflow data for Fairfax and Prince William counties in the state of Virginia

# %%
start = "2017-01-01"
end = "2017-12-31"
cs = hf.get_nwis(None, "dv", start, end, countyCd=['51059', '51061'])

# %%
cd = hf.extract_nwis_df(cs)

# %% [markdown]
# #### Plot all streamflow data for Fairfax and Prince William counties in the state of Virginia

# %%
cd.plot()
